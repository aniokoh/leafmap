# %% [markdown]
# <a href="https://colab.research.google.com/github/aniokoh/leafmap/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install pigeon-jupyter
# !pip install  pigeon-jupyter
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 45.0 MB/s eta 0:00:00
# ...
#   Created wheel for pigeon-jupyter: filename=pigeon_jupyter-0.1.0-py3-none-any.whl size=3865 sha256=ea94dcafae24968cc73a7eefa7537b5d4f6bb467bf30319e6a42b3ef67e04dd6
#   Stored in directory: /root/.cache/pip/wheels/2c/55/ef/43a86d66313cb16ff952e509365baf5ac3e60516ee4c4405b0
# Successfully built pigeon-jupyter
# ...

# %%
# Unzip dataset
# !unzip '/content/Boots and Sneakers Dataset.zip' -d '/content/Boots and Sneakers Dataset'
# Out:
# Archive:  /content/Boots and Sneakers Dataset.zip
#  extracting: /content/Boots and Sneakers Dataset/OIG (1).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (2).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (3).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (4).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (5).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (6).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (7).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (8).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (9).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (10).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (11).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (12).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (13).jpg
#  extracting: /content/Boots and Sneakers Dataset/OIG (14).jpg
# ...

# %%
# Import libraries

import os
from pigeon import annotate
from IPython.display import display, Image

# %%
folder_path = '/content/Boots and Sneakers Dataset'
image_names = os.listdir(folder_path)
image_paths = [os.path.join(folder_path, image_name) for image_name in image_names]

# %%
image_paths
# Out:
# ['/content/Boots and Sneakers Dataset/OIG (39).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (37).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (34).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (9).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (36).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (45).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (6).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (20).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (35).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (23).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (31).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (44).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (15).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (12).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (11).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (30).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (41).jpg',
#  '/content/Boots and Sneakers Dataset/OIG (7).jpg',
# ...

# %%
len(image_paths)
# Out:
# 45

# %%
label_options = ['boot', 'sneakers']

# %%
annotations = annotate(
    image_paths,
    options=label_options,
    display_fn=lambda filename: display(Image(filename=filename))
)
# Out:
# HTML(value='0 examples annotated, 46 examples left')
# ...
# Output()

# %%
annotations
# Out:
# [('/content/Boots and Sneakers Dataset/OIG (39).jpg', 'boot'),
#  ('/content/Boots and Sneakers Dataset/OIG (37).jpg', 'sneakers'),
#  ('/content/Boots and Sneakers Dataset/OIG (9).jpg', 'sneakers'),
#  ('/content/Boots and Sneakers Dataset/OIG (36).jpg', 'boot'),
#  ('/content/Boots and Sneakers Dataset/OIG (45).jpg', 'sneakers'),
#  ('/content/Boots and Sneakers Dataset/OIG (6).jpg', 'sneakers'),
#  ('/content/Boots and Sneakers Dataset/OIG (20).jpg', 'sneakers')]

# %%
import pandas as pd
df_annotation = pd.DataFrame(annotations,columns = ['filename','label'])
df_annotation
# Out:
#                                            filename     label
# 0  /content/Boots and Sneakers Dataset/OIG (39).jpg      boot
# 1  /content/Boots and Sneakers Dataset/OIG (37).jpg  sneakers
# 2   /content/Boots and Sneakers Dataset/OIG (9).jpg  sneakers
# 3  /content/Boots and Sneakers Dataset/OIG (36).jpg      boot
# 4  /content/Boots and Sneakers Dataset/OIG (45).jpg  sneakers
# 5   /content/Boots and Sneakers Dataset/OIG (6).jpg  sneakers
# 6  /content/Boots and Sneakers Dataset/OIG (20).jpg  sneakers

# %%
df_annotation.to_csv('boot_and_sneakers_annotation.csv', index=False)

# %%
pd.read_csv('/content/boot_and_sneakers_annotation.csv')
# Out:
#                                            filename     label
# 0  /content/Boots and Sneakers Dataset/OIG (39).jpg      boot
# 1  /content/Boots and Sneakers Dataset/OIG (37).jpg  sneakers
# 2   /content/Boots and Sneakers Dataset/OIG (9).jpg  sneakers
# 3  /content/Boots and Sneakers Dataset/OIG (36).jpg      boot
# 4  /content/Boots and Sneakers Dataset/OIG (45).jpg  sneakers
# 5   /content/Boots and Sneakers Dataset/OIG (6).jpg  sneakers
# 6  /content/Boots and Sneakers Dataset/OIG (20).jpg  sneakers
